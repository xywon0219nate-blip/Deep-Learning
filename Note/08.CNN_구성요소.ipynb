# %% [markdown]
# #### CNN(Convolutional Neural Network : 합성곱 신경망)
#
# ##### CNN 입장에서 본 심층 신경망의 단점
# - 입력값으로 고유 이미지 생김새 정보를 알 수 없다. (2차원 -> 1차원 변경 후 작업)
# - 심층신경망은 픽셀 하나 하나의 변화에 상당히 민감
# - 이미지 생김새를 사용할 수 없으므로 한 두 개의 픽셀이 모델 전체에 영향을 미침
# - 픽셀 한두개의 정보에도 민감하게 반응하기 위해 상당히 많은 변수를 포함 -> 학습시간이 길고 과대적합이 발생하기 쉬움

# %% [markdown]
# #### 밀집층(Dense)
# - 1차원 구조
# - 밀집층의 뉴런(노드)를 여러개 사용해서 신경망 알고리즘 출력을 만듬
# - 이미지는 원래 2차원인데 이를 1차원으로 만들어 처리하므로 이미지 모양이 없어짐
# - 원래 이미지는 2차원이니까 이를 2차원으로 처리할 수 있는 방법이 합성곱 신경망

# %% [markdown]
# #### 합성곱층
# - 이미지의 크기가 4*4
# - 필터의 커널은 3*3이고 각 입력층에 곱해지는 weight와 bias는 동일
# - 발생하는 출력의 개수는 4개 : 특성 맵
# - 특성맵의 구성은 (가로 * 세로 * 필터의 수) 로 3차원 생성

# %% [markdown]
# #### 특성맵
# - 특성맵을 할성화 출력이라고도 한다.
# - 커널 특성맵 사이에 활성화 함수(relu)가 들어가 있기 때문
# - CNN에서는 특성맵이 Feature Map

# %% [markdown]
# #### Padding
# - 입력값과 특성맵의 크기를 동일시 하자
# - sample padding : padding 사용
# - valid padding : padding 사용 X

# %% [markdown]
# #### Stride
# - 특성맵을 구성할 경우 filter의 움직이는 거리

# %% [markdown]
# 합성곱 층을 여러개 준 경우는 심층합성곱 신경망이라고 한다
